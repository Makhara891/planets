# %%
import sqlite3

from win32comext.mapi.emsabtags import PR_EMS_AB_DXA_IMP_SEQ_USN

conn = sqlite3.connect('planets.sqlite')
c = conn.cursor()

#ეს chat GPT ის დავაწერინე ბაზის გადმოწერა და შემოტანა ვცადე მარა რაღაც პრობლემები იყო და ეს გზა ვამჯობინე ჩამონათვალია პლანეტების სახელების, მათი მასების, რადიუსების, მზისგან რამდენი au თი არიან დაშორებულნი და ა.შ.
planets = [
    ("Susan-686", 2221.83, 0.72, 5760.8, 69.084, True, "Dwarf"),
    ("Jeffrey-400", 10286.3, 150.43, 6762.9, 49.814, False, "Terrestrial"),
    ("Samuel-236", 12170.29, 304.86, 267.4, 0.364, False, "Terrestrial"),
    ("Anthony-201", 41655.09, 64.51, 4475.1, 50.344, True, "Gas Giant"),
    ("Rebecca-459", 64545.79, 55.94, 3465.7, 57.908, True, "Terrestrial"),
    ("Megan-972", 72728.43, 12.93, 6402.7, 25.344, True, "Terrestrial"),
    ("Phillip-720", 23246.62, 26.33, 5520.3, 91.832, True, "Ice Giant"),
    ("John-953", 25856.34, 240.47, 947.6, 54.492, True, "Terrestrial"),
    ("Justin-665", 33835.3, 296.43, 7153.9, 10.241, True, "Terrestrial"),
    ("Jacob-513", 6536.94, 68.5, 6232.3, 33.322, False, "Gas Giant"),
    ("Zoe-585", 59401.93, 145.97, 5636.8, 9.725, True, "Terrestrial"),
    ("Kenneth-538", 30639.93, 104.98, 7031.6, 64.963, True, "Gas Giant"),
    ("Gina-442", 43311.62, 93.71, 6874.1, 9.491, False, "Ice Giant"),
    ("Heather-914", 26319.86, 251.13, 2026.1, 87.836, True, "Gas Giant"),
    ("Ryan-255", 70474.85, 299.73, 8013.3, 45.443, True, "Dwarf"),
    ("Darren-444", 66031.95, 127.86, 2687.9, 88.321, False, "Gas Giant"),
    ("Kyle-918", 18665.03, 191.59, 2856.9, 16.725, False, "Ice Giant"),
    ("Sherry-591", 14133.53, 8.89, 2409.1, 96.746, True, "Dwarf"),
    ("Brett-941", 71775.87, 229.78, 4138.7, 66.679, True, "Dwarf"),
    ("Kelli-938", 75240.25, 292.87, 6406.2, 64.665, True, "Gas Giant"),
    ("Andrew-253", 8712.79, 297.11, 843.2, 7.876, False, "Terrestrial"),
    ("Roberto-313", 1052.96, 184.85, 2166.3, 77.827, False, "Gas Giant"),
    ("Philip-140", 49714.78, 156.67, 8280.4, 13.31, True, "Dwarf"),
    ("Natalie-918", 53443.42, 143.43, 6135.6, 86.336, True, "Dwarf"),
    ("Jason-281", 46005.64, 301.68, 3302.1, 58.891, False, "Dwarf"),
    ("Michael-233", 66764.73, 195.67, 4688.5, 13.528, False, "Ice Giant"),
    ("Christopher-684", 51935.06, 317.18, 8264, 99.077, False, "Terrestrial"),
    ("Cheryl-306", 33521.54, 240.29, 509.5, 86.135, True, "Terrestrial"),
    ("Tina-903", 3352.09, 253.52, 4109.1, 92.046, True, "Gas Giant"),
    ("Sharon-732", 43792.87, 211.82, 4079.3, 21.977, True, "Gas Giant"),
    ("Taylor-633", 28443.47, 162.49, 7237, 21.053, True, "Dwarf"),
    ("William-921", 34139.36, 28.85, 9804, 51.479, False, "Gas Giant"),
    ("Jimmy-603", 62792.49, 179.08, 8327.8, 15.217, False, "Dwarf"),
    ("Sandra-288", 15103.47, 191.45, 4563.5, 76.868, True, "Dwarf"),
    ("Brian-575", 8317.33, 316.89, 2475.6, 49.437, True, "Ice Giant"),
    ("Gregory-490", 47714.98, 223.38, 7862.1, 34.384, True, "Terrestrial"),
    ("Hannah-584", 10057.54, 13.2, 2440.1, 88.806, True, "Dwarf"),
    ("Anita-531", 74629.85, 59.86, 7392.7, 24.971, False, "Dwarf"),
    ("Sue-542", 12964, 39.07, 256.1, 77.901, True, "Dwarf"),
    ("Lisa-150", 47445.78, 16.77, 1667, 89.528, False, "Gas Giant"),
    ("Raymond-262", 13850.7, 229.45, 7070.4, 50.151, True, "Dwarf"),
    ("Jonathan-547", 27775.71, 110.8, 2560.5, 77.603, True, "Terrestrial"),
    ("Timothy-553", 9189.4, 238.2, 6640.1, 2.622, True, "Terrestrial"),
    ("Crystal-107", 59836.55, 198.17, 2482.7, 94.224, True, "Dwarf"),
    ("Steven-407", 12245.18, 144.43, 44.7, 62.535, False, "Dwarf"),
    ("Jessica-360", 34828.74, 275.56, 8842.8, 28.544, True, "Ice Giant"),
    ("Marcia-869", 70029.13, 223.5, 1301.5, 37.887, False, "Terrestrial"),
    ("Joshua-369", 78176.46, 102.78, 1919.5, 54.623, True, "Terrestrial"),
    ("Jesse-925", 22430.77, 349.48, 6693.6, 42.646, True, "Dwarf"),
    ("Catherine-214", 1155.77, 85.88, 2167.5, 61.864, False, "Terrestrial"),
    ("Amy-398", 64153.81, 347.04, 1967.2, 4.303, True, "Gas Giant"),
    ("Sarah-494", 68086.04, 284.03, 9701.5, 57.233, False, "Terrestrial"),
    ("Annette-229", 48051, 255.98, 2603.2, 22.921, False, "Terrestrial"),
    ("Peter-222", 41617.25, 184.3, 6704.7, 25.756, True, "Gas Giant"),
    ("Carlos-219", 14236, 227, 9519.1, 56.714, True, "Dwarf"),
    ("Adrienne-696", 32059.77, 296.53, 9340.7, 4.255, True, "Ice Giant"),
    ("Andrea-507", 59697.74, 237.72, 5656.5, 80.271, False, "Dwarf")
]

#ეს ქმნის ცხრილს სახელად planets იმ შემთხვევაში თუ უკვე არ არსებობს
c.execute("""CREATE TABLE IF NOT EXISTS planets (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    name VARCHAR(255),
    radius FLOAT NOT NULL,
    mass FLOAT NOT NULL,
    orbital_period FLOAT NOT NULL,
    distance_from_star_au FLOAT NOT NULL,
    has_rings INTEGER,
    planet_type VARCHAR(255))
""")


#earth = ("Earth", 6371, 5.972e24, 365.25, 1.0, 0, "Terrestrial") #ეს chat GPT ის დავაწერინე ზუსტი დედამიწის მონაცემები (radius, mass, orbital_period, distance_from_star_au, has_rings, planet_type)


# c.executemany(
#     "INSERT INTO planets (name, radius, mass, orbital_period, distance_from_star_au, has_rings, planet_type) VALUES (?, ?, ?, ?, ?, ?, ?)",
#     planets
# )
#
# c.execute("INSERT INTO planets(name, radius, mass, orbital_period, distance_from_star_au, has_rings, planet_type) VALUES (?, ?, ?, ?, ?, ?, ?)",
#           earth
# )


# ui = (70.5, "Earth")
#
# c.execute("UPDATE planets SET radius = ? WHERE name = ?", (ui[0], ui[1])) #ცვლის იმ პლანეტის რადიუსს 70.5 ზე რომლის სახელიც არის 'Earth'


#ეს ბრძანება შლის იმ პლანეტის row-ს რომლის სახელია Brian-575 და პლანეტის ტიპია ყინულის გიგანტი
# ui = ('Brian-575', 'Ice Giant')

# c.execute("DELETE FROM planets WHERE name = ? and planet_type = ?", (ui[0], ui[1]))













conn.commit()

# m = 150
# t = 'Gas Giant'
#
# c.execute("SELECT * FROM planets WHERE mass > ? AND planet_type = ?", (m, t))
# print(c.fetchone())
# print(c.fetchmany(6))
#ცხრილში ეძებს და გამოაქვს ყველა ისეთი პლანეტა რომლის მასაც არის 150 ზე მეტი და არის გაზის გიგანტი

conn.close()
